# %% [markdown]
# Technological Institute of the Philippines | Quezon City - Computer Engineering
# --- | ---
# Course Code: | CPE 018
# Code Title: | Emerging Technologies in CpE 1 - Fundamentals of Computer Vision
# 1st Semester | AY 2023-2024
# <hr> | <hr>
# <u>**ACTIVITY NO.** | **TITLE**
# **Name** | LastName, FirstName
# **Section** | CPE31Sx
# **Date Performed**: |
# **Date Submitted**: |
# **Instructor**: | Dr. Jonathan V. Taylar / Engr. Verlyn V. Nojor / Engr. Roman M. Richard
#
# <hr>

# %% [markdown]
# ## 1. Objectives

# %% [markdown]
# This activity aims to enable students to perform data preparation and face recognition on their own generated dataset.

# %% [markdown]
# ## 2. Intended Learning Outcomes (ILOs)
# After this activity, the students should be able to:
# * Utilize data preparation techniques for images.
# * Perform Face Recognition using multiple algorithms.
# * Evaluate the performance of different algorithms.

# %% [markdown]
# ## 3. Procedures and Outputs

# %% [markdown]
# ### Preparing the training data

# %% [markdown]
# Now that we have our data, we need to load these sample pictures into our face recognition algorithms. All face recognition algorithms take two parameters in their `train()` method: an array of images and an array of labels. What do these labels represent? They are the IDs of a certain individual/face so that when face recognition is performed, we not only know the person was recognized but also who—among the many people available in our database—the person is.
#
# To do that, we need to create a comma-separated value (CSV) file, which will contain the path to a sample picture followed by the ID of that person.

# %% [markdown]
# **Include a Screenshot of Your Dataset Here**

# %% [markdown]
# ---

# %% [markdown]
# ### Loading the data and recognizing faces

# %%
# %pip install opencv-python opencv-contrib-python numpy

# %% [markdown]
# Next up, we need to load these two resources (the array of images and CSV file) into the face recognition algorithm, so it can be trained to recognize our face. To do this, we build a function that reads the CSV file and—for each line of the file—loads the image at the corresponding path into the images array and the ID into the labels array.

# %%
import numpy as np
import os
import cv2

# Load Haar cascade for face detection
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

# Paths
dataset_path = "JOHN/"
model_path = "face_model.yml"
label_dict_path = "label_dictionary.npy"

def read_images(path):
    """ Reads images, detects faces, and prepares training data. """
    X, y = [], []
    label_dict = {}
    label_id = 0  

    for subdirname in os.listdir(path):
        subject_path = os.path.join(path, subdirname)
        if not os.path.isdir(subject_path):
            continue  

        label_dict[label_id] = subdirname  

        for filename in os.listdir(subject_path):
            filepath = os.path.join(subject_path, filename)
            img = cv2.imread(filepath, cv2.IMREAD_GRAYSCALE)

            if img is None:
                print(f"Skipping {filename}: Invalid image")
                continue  

            faces = face_cascade.detectMultiScale(img, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
            if len(faces) == 0:
                print(f"Skipping {filename}: No face detected")
                continue  

            for (x, y_, w, h) in faces:
                face = img[y_:y_ + h, x:x + w]
                face = cv2.resize(face, (200, 200))

                X.append(face)
                y.append(label_id)

        label_id += 1

    return X, y, label_dict

# Read images and extract faces
print("Reading images and training the model...")
X, y, label_dict = read_images(dataset_path)

if len(X) == 0 or len(y) == 0:
    print("Error: No faces found. Check your dataset.")
    exit()

# Convert X and y to correct NumPy array format
X = np.array(X, dtype=np.uint8)  # Convert list of images to NumPy array
y = np.array(y, dtype=np.int32)  # Convert labels to NumPy array

recognizer = cv2.face.EigenFaceRecognizer_create()

# Train the recognizer
recognizer.train(X, y)

# Save trained model and labels
recognizer.save(model_path)
np.save(label_dict_path, label_dict)

print(f"Training complete! Model saved as '{model_path}'. Label dictionary saved as '{label_dict_path}'.")
print("Label dictionary:", label_dict)
# Out:
# Reading images and training the model...
# Training complete! Model saved as 'face_model.yml'. Label dictionary saved as 'label_dictionary.npy'.
# Label dictionary: {0: 'john', 1: 'naomi'}

# %% [markdown]
# **Question: Run the function above on your generated dataset. Provide an analysis and note all the challenges you have encountered running this code.**

# %% [markdown]
# ---

# %% [markdown]
# ### Performing Face Recognition Algorithms

# %% [markdown]
# Here is a sample script for testing the Face Recognition Algorithm. In this section, we're going to follow the same process but with different algorithms for face recognitions, namely:
# - Eigenface Recognition
# - Fisherface Recognition
# - Local Binary Pattern Histograms (LBPH) Recognition

# %%
import numpy as np
import cv2
import os

def read_images(path, face_cascade):
    """ Reads images from the dataset and prepares training data. """
    X, y = [], []
    label_dict = {}
    label_id = 0

    for subdirname in os.listdir(path):
        subject_path = os.path.join(path, subdirname)
        if not os.path.isdir(subject_path):
            continue

        label_dict[label_id] = subdirname

        for filename in os.listdir(subject_path):
            filepath = os.path.join(subject_path, filename)
            img = cv2.imread(filepath, cv2.IMREAD_GRAYSCALE)

            if img is None:
                continue

            faces = face_cascade.detectMultiScale(img, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
            for (x, y_, w, h) in faces:
                face = img[y_:y_ + h, x:x + w]
                face = cv2.resize(face, (200, 200))
                X.append(face)
                y.append(label_id)

        label_id += 1

    return np.array(X, dtype=np.uint8), np.array(y, dtype=np.int32), label_dict  # Return label_dict

def face_rec():
    dataset_path = "JOHN/"  
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    X, y, label_dict = read_images(dataset_path, face_cascade)

    model = cv2.face.EigenFaceRecognizer_create()
    model.train(X, y)

    camera = cv2.VideoCapture(0)

    while True:
        ret, img = camera.read()
        if not ret:
            break

        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)  
        faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

        for (x, y, w, h) in faces:
            cv2.rectangle(img, (x, y), (x + w, y + h), (255, 0, 0), 2)
            roi = gray[y:y + h, x:x + w]
            roi = cv2.resize(roi, (200, 200), interpolation=cv2.INTER_LINEAR)

            try:
                params = model.predict(roi)
                label = label_dict[params[0]] if params[0] in label_dict else "Unknown"
                print(f"Predicted label: {params[0]}, Confidence: {params[1]:.2f}")  # Debugging information
                cv2.putText(img, f"{label}, {params[1]:.2f}", (x, y - 20), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)

            except Exception as e:
                print(f"Prediction error: {e}")  # Debugging information
                continue

        cv2.imshow("camera", img)
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break

    camera.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    face_rec()
# Out:
# Predicted label: 0, Confidence: 5647.36
# Predicted label: 0, Confidence: 6062.50
# Predicted label: 1, Confidence: 9755.50
# Predicted label: 0, Confidence: 6062.50
# Predicted label: 1, Confidence: 9755.50
# Predicted label: 0, Confidence: 6103.70
# Predicted label: 0, Confidence: 6104.58
# Predicted label: 0, Confidence: 4388.10
# Predicted label: 0, Confidence: 4388.10
# Predicted label: 0, Confidence: 4701.20
# Predicted label: 0, Confidence: 6384.43
# Predicted label: 0, Confidence: 6100.79
# Predicted label: 0, Confidence: 4534.53
# Predicted label: 0, Confidence: 5998.60
# Predicted label: 0, Confidence: 6014.52
# Predicted label: 0, Confidence: 6288.30
# Predicted label: 0, Confidence: 5798.12
# Predicted label: 0, Confidence: 5798.12
# Predicted label: 0, Confidence: 6265.72
# Predicted label: 0, Confidence: 6490.38
# Predicted label: 0, Confidence: 6492.73
# Predicted label: 0, Confidence: 6557.93
# Predicted label: 0, Confidence: 6752.62
# Predicted label: 0, Confidence: 6752.62
# Predicted label: 0, Confidence: 6737.19
# Predicted label: 0, Confidence: 6856.13
# Predicted label: 0, Confidence: 6396.22
# Predicted label: 0, Confidence: 7386.14
# Predicted label: 0, Confidence: 7386.14
# Predicted label: 0, Confidence: 6485.75
# Predicted label: 0, Confidence: 6842.99
# Predicted label: 0, Confidence: 6510.25
# Predicted label: 0, Confidence: 6511.00
# Predicted label: 0, Confidence: 6852.82
# Predicted label: 0, Confidence: 6810.78
# Predicted label: 0, Confidence: 6810.78
# Predicted label: 0, Confidence: 6562.63
# Predicted label: 0, Confidence: 6558.59
# Predicted label: 0, Confidence: 6397.06
# Predicted label: 0, Confidence: 6553.93
# Predicted label: 0, Confidence: 6553.93
# Predicted label: 1, Confidence: 6098.79
# Predicted label: 1, Confidence: 6074.53
# Predicted label: 1, Confidence: 6074.53
# Predicted label: 1, Confidence: 6379.27
# Predicted label: 0, Confidence: 6514.93
# Predicted label: 0, Confidence: 6514.93
# Predicted label: 0, Confidence: 6542.93
# Predicted label: 0, Confidence: 6305.95
# Predicted label: 0, Confidence: 6149.89
# Predicted label: 0, Confidence: 6055.88
# Predicted label: 0, Confidence: 6055.88
# Predicted label: 0, Confidence: 5849.94
# Predicted label: 0, Confidence: 6144.79
# Predicted label: 0, Confidence: 6144.79
# Predicted label: 0, Confidence: 6201.39
# Predicted label: 0, Confidence: 6201.39
# Predicted label: 1, Confidence: 6105.40
# Predicted label: 0, Confidence: 6274.52
# Predicted label: 0, Confidence: 6298.43
# Predicted label: 0, Confidence: 6363.26
# Predicted label: 0, Confidence: 6363.26
# Predicted label: 1, Confidence: 6307.83
# Predicted label: 1, Confidence: 6712.31
# Predicted label: 1, Confidence: 6712.31
# Predicted label: 1, Confidence: 6506.98
# Predicted label: 1, Confidence: 6350.14
# Predicted label: 1, Confidence: 6454.42
# Predicted label: 1, Confidence: 6454.42
# Predicted label: 1, Confidence: 6438.66
# Predicted label: 1, Confidence: 6343.22
# Predicted label: 1, Confidence: 6343.22
# Predicted label: 1, Confidence: 6404.36
# Predicted label: 1, Confidence: 6088.11
# Predicted label: 1, Confidence: 6040.19
# Predicted label: 1, Confidence: 6040.19
# Predicted label: 1, Confidence: 6185.69
# Predicted label: 1, Confidence: 6185.69
# Predicted label: 1, Confidence: 6414.92
# Predicted label: 1, Confidence: 6385.61
# Predicted label: 1, Confidence: 6497.03
# Predicted label: 1, Confidence: 6497.03
# Predicted label: 1, Confidence: 6221.33
# Predicted label: 1, Confidence: 6235.01
# Predicted label: 1, Confidence: 6398.76
# Predicted label: 1, Confidence: 6398.76
# Predicted label: 1, Confidence: 6394.17
# Predicted label: 1, Confidence: 6402.76
# Predicted label: 1, Confidence: 6402.76
# Predicted label: 1, Confidence: 6423.50
# Predicted label: 1, Confidence: 6375.72
# Predicted label: 1, Confidence: 6414.28
# Predicted label: 1, Confidence: 6273.77
# Predicted label: 1, Confidence: 6273.77
# Predicted label: 1, Confidence: 6302.14
# Predicted label: 1, Confidence: 6479.08
# Predicted label: 0, Confidence: 6012.21
# Predicted label: 1, Confidence: 6479.08
# Predicted label: 0, Confidence: 6012.21
# Predicted label: 1, Confidence: 6252.56
# Predicted label: 1, Confidence: 6397.04
# Predicted label: 1, Confidence: 6421.41
# Predicted label: 1, Confidence: 6383.32
# Predicted label: 1, Confidence: 6383.32
# Predicted label: 1, Confidence: 6408.07
# Predicted label: 1, Confidence: 6425.77
# Predicted label: 1, Confidence: 6221.57
# Predicted label: 1, Confidence: 6423.17
# Predicted label: 1, Confidence: 6355.57
# Predicted label: 1, Confidence: 6355.57
# Predicted label: 1, Confidence: 6403.44
# Predicted label: 1, Confidence: 6319.75
# Predicted label: 1, Confidence: 6199.59
# Predicted label: 1, Confidence: 6199.59
# Predicted label: 1, Confidence: 6165.13
# Predicted label: 1, Confidence: 6144.48
# Predicted label: 1, Confidence: 6113.06
# Predicted label: 1, Confidence: 6113.06
# Predicted label: 1, Confidence: 6155.63
# Predicted label: 0, Confidence: 6263.19
# Predicted label: 0, Confidence: 6133.37
# Predicted label: 0, Confidence: 6133.37
# Predicted label: 1, Confidence: 5108.93
# Predicted label: 0, Confidence: 4831.55
# Predicted label: 0, Confidence: 4831.55
# Predicted label: 0, Confidence: 4710.30
# Predicted label: 0, Confidence: 5854.68
# Predicted label: 0, Confidence: 5854.68
# Predicted label: 0, Confidence: 5872.42
# Predicted label: 1, Confidence: 5749.30
# Predicted label: 1, Confidence: 5712.74
# Predicted label: 1, Confidence: 5712.74
# Predicted label: 1, Confidence: 5708.32
# Predicted label: 1, Confidence: 5960.97
# Predicted label: 1, Confidence: 5960.97
# Predicted label: 1, Confidence: 5988.97
# Predicted label: 0, Confidence: 5690.14
# Predicted label: 0, Confidence: 5145.79
# Predicted label: 1, Confidence: 5637.51
# Predicted label: 1, Confidence: 5637.51
# Predicted label: 1, Confidence: 5782.31
# Predicted label: 1, Confidence: 5782.31
# Predicted label: 1, Confidence: 5743.41
# Predicted label: 1, Confidence: 5630.90
# Predicted label: 1, Confidence: 5630.90
# Predicted label: 0, Confidence: 5720.53
# Predicted label: 0, Confidence: 5720.53
# Predicted label: 0, Confidence: 5567.20
# Predicted label: 1, Confidence: 5917.29
# Predicted label: 0, Confidence: 5926.30
# Predicted label: 0, Confidence: 5926.30
# Predicted label: 0, Confidence: 5895.56
# Predicted label: 0, Confidence: 6069.43
# Predicted label: 0, Confidence: 6069.43
# Predicted label: 0, Confidence: 5412.71
# Predicted label: 0, Confidence: 5173.92
# Predicted label: 0, Confidence: 5173.92
# Predicted label: 0, Confidence: 5208.36
# Predicted label: 0, Confidence: 5208.36
# Predicted label: 0, Confidence: 5805.70
# Predicted label: 0, Confidence: 5805.70
# Predicted label: 0, Confidence: 5837.52
# Predicted label: 0, Confidence: 5991.93
# Predicted label: 0, Confidence: 5835.37
# Predicted label: 1, Confidence: 3496.92
# Predicted label: 1, Confidence: 3644.64
# Predicted label: 1, Confidence: 3409.71
# Predicted label: 1, Confidence: 5729.92
# Predicted label: 0, Confidence: 5979.01
# Predicted label: 0, Confidence: 4590.13
# Predicted label: 0, Confidence: 4654.54
# Predicted label: 0, Confidence: 5877.13
# Predicted label: 1, Confidence: 6049.88
# Predicted label: 1, Confidence: 6261.25
# Predicted label: 1, Confidence: 5409.92
# Predicted label: 0, Confidence: 5403.17
# Predicted label: 0, Confidence: 5403.17
# Predicted label: 1, Confidence: 7023.15
# Predicted label: 0, Confidence: 6845.34
# Predicted label: 0, Confidence: 6721.37
# Predicted label: 0, Confidence: 6721.37
# Predicted label: 0, Confidence: 6645.07
# Predicted label: 0, Confidence: 6645.07
# Predicted label: 0, Confidence: 5053.34
# Predicted label: 1, Confidence: 6451.08
# Predicted label: 0, Confidence: 5242.25
# Predicted label: 0, Confidence: 5234.66
# Predicted label: 0, Confidence: 5127.54
# Predicted label: 0, Confidence: 5127.54
# Predicted label: 0, Confidence: 4979.61
# Predicted label: 0, Confidence: 4979.61
# Predicted label: 0, Confidence: 4989.53
# Predicted label: 1, Confidence: 6490.77
# Predicted label: 0, Confidence: 5181.18
# Predicted label: 1, Confidence: 6582.59
# Predicted label: 0, Confidence: 5441.58
# Predicted label: 1, Confidence: 6571.34
# Predicted label: 0, Confidence: 5441.58
# Predicted label: 1, Confidence: 6571.34
# Predicted label: 0, Confidence: 5139.70
# Predicted label: 0, Confidence: 5139.70
# Predicted label: 0, Confidence: 5142.24
# Predicted label: 0, Confidence: 5155.97
# Predicted label: 0, Confidence: 5037.61
# Predicted label: 0, Confidence: 5037.61
# Predicted label: 0, Confidence: 5123.70
# Predicted label: 0, Confidence: 5123.70
# Predicted label: 0, Confidence: 5167.89
# Predicted label: 0, Confidence: 5001.40
# Predicted label: 0, Confidence: 5000.75
# Predicted label: 0, Confidence: 5000.75
# Predicted label: 0, Confidence: 5036.02
# Predicted label: 0, Confidence: 5036.02
# Predicted label: 0, Confidence: 5037.18
# Predicted label: 0, Confidence: 5205.66
# Predicted label: 0, Confidence: 5243.21
# Predicted label: 0, Confidence: 5103.21
# Predicted label: 0, Confidence: 5104.65
# Predicted label: 0, Confidence: 5104.65
# Predicted label: 1, Confidence: 6722.99
# Predicted label: 0, Confidence: 5191.28
# Predicted label: 1, Confidence: 6722.99
# Predicted label: 0, Confidence: 5191.28
# Predicted label: 0, Confidence: 5014.42
# Predicted label: 0, Confidence: 5042.61
# Predicted label: 0, Confidence: 5042.61
# Predicted label: 1, Confidence: 8199.07
# Predicted label: 0, Confidence: 4991.33
# Predicted label: 0, Confidence: 4991.33
# Predicted label: 1, Confidence: 8199.07
# Predicted label: 0, Confidence: 5004.40
# Predicted label: 0, Confidence: 5010.47
# Predicted label: 0, Confidence: 5073.19
# Predicted label: 0, Confidence: 5073.19
# Predicted label: 0, Confidence: 4974.95
# Predicted label: 0, Confidence: 4925.31
# Predicted label: 0, Confidence: 4925.31
# Predicted label: 0, Confidence: 4925.31
# Predicted label: 0, Confidence: 5040.08
# Predicted label: 0, Confidence: 4914.60
# Predicted label: 0, Confidence: 4914.60
# Predicted label: 0, Confidence: 4914.60
# Predicted label: 0, Confidence: 4928.69
# Predicted label: 0, Confidence: 4928.69
# Predicted label: 0, Confidence: 4863.89
# Predicted label: 0, Confidence: 4878.78
# Predicted label: 0, Confidence: 4878.78
# Predicted label: 0, Confidence: 4854.85
# Predicted label: 0, Confidence: 4961.79
# Predicted label: 0, Confidence: 4915.62
# Predicted label: 0, Confidence: 4915.62
# Predicted label: 0, Confidence: 4916.40
# Predicted label: 0, Confidence: 4918.43
# Predicted label: 0, Confidence: 4918.43
# Predicted label: 0, Confidence: 4867.24
# Predicted label: 0, Confidence: 4867.24
# Predicted label: 0, Confidence: 4883.31
# Predicted label: 0, Confidence: 4903.30
# Predicted label: 0, Confidence: 4903.30
# Predicted label: 0, Confidence: 4963.91
# Predicted label: 0, Confidence: 4963.91
# Predicted label: 0, Confidence: 4990.64
# Predicted label: 0, Confidence: 4944.05
# Predicted label: 0, Confidence: 4944.54
# Predicted label: 0, Confidence: 4944.54
# Predicted label: 0, Confidence: 4944.54
# Predicted label: 0, Confidence: 4871.84
# Predicted label: 0, Confidence: 4871.84
# Predicted label: 0, Confidence: 4992.45
# Predicted label: 0, Confidence: 4991.87
# Predicted label: 1, Confidence: 6679.86
# Predicted label: 0, Confidence: 4991.87
# Predicted label: 1, Confidence: 6679.86
# Predicted label: 0, Confidence: 4977.35
# Predicted label: 0, Confidence: 6803.96
# Predicted label: 0, Confidence: 5037.04
# Predicted label: 1, Confidence: 6900.47
# Predicted label: 0, Confidence: 4863.87
# Predicted label: 0, Confidence: 7320.70
# Predicted label: 0, Confidence: 4863.87
# Predicted label: 0, Confidence: 7320.70
# Predicted label: 0, Confidence: 6319.97
# Predicted label: 0, Confidence: 6319.97
# Predicted label: 0, Confidence: 6442.90
# Predicted label: 0, Confidence: 6395.82
# Predicted label: 0, Confidence: 6395.82
# Predicted label: 0, Confidence: 4467.70
# Predicted label: 0, Confidence: 4467.70
# Predicted label: 0, Confidence: 6598.34
# Predicted label: 0, Confidence: 6598.34
# Predicted label: 0, Confidence: 4721.82
# Predicted label: 0, Confidence: 4721.82
# Predicted label: 0, Confidence: 4721.82
# Predicted label: 0, Confidence: 4863.20
# Predicted label: 0, Confidence: 4863.20
# Predicted label: 0, Confidence: 4766.52
# Predicted label: 0, Confidence: 4766.52
# Predicted label: 0, Confidence: 4766.52
# Predicted label: 0, Confidence: 4915.64
# Predicted label: 0, Confidence: 4915.64
# Predicted label: 0, Confidence: 4887.35
# Predicted label: 0, Confidence: 4871.14
# Predicted label: 0, Confidence: 4871.14
# Predicted label: 0, Confidence: 4871.14
# Predicted label: 0, Confidence: 4890.22
# Predicted label: 0, Confidence: 4966.82
# Predicted label: 0, Confidence: 4966.82
# Predicted label: 0, Confidence: 4996.81
# Predicted label: 0, Confidence: 4883.64
# Predicted label: 0, Confidence: 4996.81
# Predicted label: 0, Confidence: 4883.64
# Predicted label: 0, Confidence: 4866.68
# Predicted label: 0, Confidence: 4819.71
# Predicted label: 0, Confidence: 4938.00
# Predicted label: 0, Confidence: 4819.71
# Predicted label: 0, Confidence: 4938.00
# Predicted label: 0, Confidence: 4997.15
# Predicted label: 0, Confidence: 4997.15
# Predicted label: 0, Confidence: 4927.13
# Predicted label: 0, Confidence: 4905.27
# Predicted label: 0, Confidence: 4927.13
# Predicted label: 0, Confidence: 4905.27
# Predicted label: 0, Confidence: 5056.98
# Predicted label: 0, Confidence: 4963.29
# Predicted label: 0, Confidence: 5056.98
# Predicted label: 0, Confidence: 4963.29
# Predicted label: 0, Confidence: 5136.22
# Predicted label: 0, Confidence: 5006.79
# Predicted label: 0, Confidence: 5436.12
# Predicted label: 0, Confidence: 5003.45
# Predicted label: 0, Confidence: 5436.12
# Predicted label: 0, Confidence: 5003.45
# Predicted label: 0, Confidence: 4968.10
# Predicted label: 0, Confidence: 4968.10
# Predicted label: 0, Confidence: 4878.97
# Predicted label: 0, Confidence: 4836.95
# Predicted label: 0, Confidence: 4938.00
# Predicted label: 0, Confidence: 4938.00
# Predicted label: 0, Confidence: 4981.20
# Predicted label: 0, Confidence: 4981.20
# Predicted label: 0, Confidence: 5840.35
# Predicted label: 0, Confidence: 6155.38
# Predicted label: 0, Confidence: 6155.38
# Predicted label: 1, Confidence: 6812.61
# Predicted label: 1, Confidence: 6812.61
# Predicted label: 1, Confidence: 6883.45
# Predicted label: 1, Confidence: 6903.66
# Predicted label: 1, Confidence: 6903.66
# Predicted label: 1, Confidence: 6730.52
# Predicted label: 1, Confidence: 6751.25
# Predicted label: 1, Confidence: 6751.25
# Predicted label: 1, Confidence: 6650.30
# Predicted label: 1, Confidence: 6616.12
# Predicted label: 1, Confidence: 6657.16
# Predicted label: 1, Confidence: 6946.23
# Predicted label: 1, Confidence: 6946.23
# Predicted label: 1, Confidence: 6903.99
# Predicted label: 1, Confidence: 6791.90
# Predicted label: 1, Confidence: 6791.90
# Predicted label: 1, Confidence: 6656.54
# Predicted label: 1, Confidence: 6649.20
# Predicted label: 1, Confidence: 6636.10
# Predicted label: 1, Confidence: 6636.10
# Predicted label: 1, Confidence: 6734.84
# Predicted label: 1, Confidence: 6671.05
# Predicted label: 1, Confidence: 6713.70
# Predicted label: 1, Confidence: 6713.70
# Predicted label: 1, Confidence: 6665.25
# Predicted label: 1, Confidence: 6712.01
# Predicted label: 1, Confidence: 6712.01
# Predicted label: 1, Confidence: 6662.11
# Predicted label: 1, Confidence: 6742.70
# Predicted label: 1, Confidence: 6714.16
# Predicted label: 1, Confidence: 6729.66
# Predicted label: 1, Confidence: 6660.02
# Predicted label: 1, Confidence: 6660.02
# Predicted label: 1, Confidence: 6629.97
# Predicted label: 1, Confidence: 6608.47
# Predicted label: 1, Confidence: 6569.03
# Predicted label: 1, Confidence: 6569.03
# Predicted label: 1, Confidence: 6657.57
# Predicted label: 1, Confidence: 6640.40
# Predicted label: 1, Confidence: 6697.46
# Predicted label: 1, Confidence: 6697.46
# Predicted label: 1, Confidence: 9384.12
# Predicted label: 1, Confidence: 9384.12
# Predicted label: 0, Confidence: 7039.98
# Predicted label: 0, Confidence: 7814.59
# Predicted label: 1, Confidence: 9053.54
# Predicted label: 1, Confidence: 7007.13
# Predicted label: 1, Confidence: 6488.27
# Predicted label: 1, Confidence: 6488.27
# Predicted label: 0, Confidence: 6520.24
# Predicted label: 0, Confidence: 6520.24
# Predicted label: 0, Confidence: 6676.30
# Predicted label: 0, Confidence: 6676.30
# Predicted label: 0, Confidence: 6420.73
# Predicted label: 0, Confidence: 7694.42
# Predicted label: 0, Confidence: 4671.74
# Predicted label: 0, Confidence: 10113.46
# Predicted label: 0, Confidence: 4628.96
# Predicted label: 0, Confidence: 4760.14
# Predicted label: 0, Confidence: 9669.11
# Predicted label: 0, Confidence: 9669.11
# Predicted label: 0, Confidence: 9526.97
# Predicted label: 0, Confidence: 9061.29
# Predicted label: 0, Confidence: 4450.22
# Predicted label: 0, Confidence: 9513.90
# Predicted label: 0, Confidence: 8419.56
# Predicted label: 0, Confidence: 4748.26
# Predicted label: 0, Confidence: 4631.11
# Predicted label: 0, Confidence: 4631.11
# Predicted label: 0, Confidence: 7776.90
# Predicted label: 0, Confidence: 7510.57
# Predicted label: 0, Confidence: 6786.48
# Predicted label: 0, Confidence: 7072.79
# Predicted label: 0, Confidence: 4601.25
# Predicted label: 0, Confidence: 7005.07
# Predicted label: 0, Confidence: 4601.25
# Predicted label: 0, Confidence: 7005.07
# Predicted label: 0, Confidence: 4708.78
# Predicted label: 0, Confidence: 6858.02
# Predicted label: 0, Confidence: 7697.88
# Predicted label: 0, Confidence: 7697.88
# Predicted label: 0, Confidence: 6964.40
# Predicted label: 0, Confidence: 7292.51
# Predicted label: 0, Confidence: 7233.03
# Predicted label: 0, Confidence: 5619.67
# Predicted label: 0, Confidence: 7233.03
# Predicted label: 0, Confidence: 5619.67
# Predicted label: 0, Confidence: 5620.81
# Predicted label: 0, Confidence: 5827.09
# Predicted label: 0, Confidence: 5969.89
# Predicted label: 0, Confidence: 5709.45
# Predicted label: 0, Confidence: 5709.45
# Predicted label: 0, Confidence: 5701.17
# Predicted label: 0, Confidence: 5827.08
# Predicted label: 0, Confidence: 5734.03
# Predicted label: 0, Confidence: 5831.77
# Predicted label: 0, Confidence: 5671.61
# Predicted label: 0, Confidence: 5831.77
# Predicted label: 0, Confidence: 5671.61
# Predicted label: 0, Confidence: 5648.02
# Predicted label: 0, Confidence: 5747.50
# Predicted label: 0, Confidence: 5648.55
# Predicted label: 0, Confidence: 5648.55
# Predicted label: 0, Confidence: 6036.51
# Predicted label: 0, Confidence: 5922.17
# Predicted label: 0, Confidence: 5922.17
# Predicted label: 0, Confidence: 6070.66
# Predicted label: 0, Confidence: 6111.82
# Predicted label: 0, Confidence: 6248.60
# Predicted label: 0, Confidence: 6310.92
# Predicted label: 0, Confidence: 6310.92
# Predicted label: 0, Confidence: 5873.58
# Predicted label: 0, Confidence: 6105.20
# Predicted label: 0, Confidence: 6105.20
# Predicted label: 0, Confidence: 6090.47
# Predicted label: 0, Confidence: 6354.52
# Predicted label: 0, Confidence: 6309.61
# Predicted label: 0, Confidence: 6309.61
# Predicted label: 0, Confidence: 6090.82
# Predicted label: 0, Confidence: 6090.82
# Predicted label: 0, Confidence: 6115.07
# Predicted label: 0, Confidence: 6227.31
# Predicted label: 0, Confidence: 6106.31
# Predicted label: 0, Confidence: 6388.48
# Predicted label: 0, Confidence: 6388.48
# Predicted label: 0, Confidence: 5961.52
# Predicted label: 0, Confidence: 8044.87
# Predicted label: 0, Confidence: 7319.21
# Predicted label: 0, Confidence: 7319.21
# Predicted label: 0, Confidence: 7559.51
# Predicted label: 0, Confidence: 7541.27
# Predicted label: 1, Confidence: 9633.96
# Predicted label: 1, Confidence: 9633.96
# Predicted label: 0, Confidence: 5539.79
# Predicted label: 0, Confidence: 5539.79

# %% [markdown]
# **Question: Provide an analysis of the sample script for the process using the Eigenface Model. What is the sample code doing? Are you able to troubleshoot any problems encountered?**

# %% [markdown]
# ---
# Perform the remaining face recognition techniques by using the same (or modified) process from the sample code:
#
# - `model = cv2.face.createFisherFaceRecognizer()`
# - `model = cv2.face.createLBPHFaceRecognizer()`

# %%
import numpy as np
import os
import cv2

# Load Haar cascade for face detection
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

# Paths
dataset_path = "JOHN/"
model_path = "face_model_lbph.yml"
label_dict_path = "label_dictionary_lbph.npy"

def read_images(path):
    """ Reads images, detects faces, and prepares training data. """
    X, y = [], []
    label_dict = {}
    label_id = 0  

    for subdirname in os.listdir(path):
        subject_path = os.path.join(path, subdirname)
        if not os.path.isdir(subject_path):
            continue  

        label_dict[label_id] = subdirname  

        for filename in os.listdir(subject_path):
            filepath = os.path.join(subject_path, filename)
            img = cv2.imread(filepath, cv2.IMREAD_GRAYSCALE)

            if img is None:
                print(f"Skipping {filename}: Invalid image")
                continue  

            faces = face_cascade.detectMultiScale(img, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
            if len(faces) == 0:
                print(f"Skipping {filename}: No face detected")
                continue  

            for (x, y_, w, h) in faces:
                face = img[y_:y_ + h, x:x + w]
                face = cv2.resize(face, (200, 200))

                X.append(face)
                y.append(label_id)

        label_id += 1

    return X, y, label_dict

# Read images and extract faces
print("Reading images and training the LBPH model...")
X, y, label_dict = read_images(dataset_path)

if len(X) == 0 or len(y) == 0:
    print("Error: No faces found. Check your dataset.")
    exit()

# Convert X and y to correct NumPy array format
X = np.array(X, dtype=np.uint8)
y = np.array(y, dtype=np.int32)

# Create LBPH recognizer
recognizer = cv2.face.LBPHFaceRecognizer_create()

# Train the recognizer
recognizer.train(X, y)

# Save trained model and labels
recognizer.save(model_path)
np.save(label_dict_path, label_dict)

print(f"Training complete! Model saved as '{model_path}'. Label dictionary saved as '{label_dict_path}'.")
print("Label dictionary:", label_dict)
# Out:
# Reading images and training the LBPH model...
# Training complete! Model saved as 'face_model_lbph.yml'. Label dictionary saved as 'label_dictionary_lbph.npy'.
# Label dictionary: {0: 'john', 1: 'naomi'}

# %%
import numpy as np
import cv2
import os

def read_images(path, face_cascade):
    """ Reads images from the dataset and prepares training data. """
    X, y = [], []
    label_dict = {}
    label_id = 0

    for subdirname in os.listdir(path):
        subject_path = os.path.join(path, subdirname)
        if not os.path.isdir(subject_path):
            continue

        label_dict[label_id] = subdirname

        for filename in os.listdir(subject_path):
            filepath = os.path.join(subject_path, filename)
            img = cv2.imread(filepath, cv2.IMREAD_GRAYSCALE)

            if img is None:
                continue

            faces = face_cascade.detectMultiScale(img, scaleFactor=1.8, minNeighbors=5, minSize=(30, 30))
            for (x, y_, w, h) in faces:
                face = img[y_:y_ + h, x:x + w]
                face = cv2.resize(face, (200, 200))
                X.append(face)
                y.append(label_id)

        label_id += 1

    return np.array(X, dtype=np.uint8), np.array(y, dtype=np.int32), label_dict  # Return label_dict

def face_rec():
    dataset_path = "JOHN/"  
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    X, y, label_dict = read_images(dataset_path, face_cascade)

    model = cv2.face.EigenFaceRecognizer_create()
    model.train(X, y)

    camera = cv2.VideoCapture(0)

    while True:
        ret, img = camera.read()
        if not ret:
            break

        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)  
        faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

        for (x, y, w, h) in faces:
            cv2.rectangle(img, (x, y), (x + w, y + h), (255, 0, 0), 2)
            roi = gray[y:y + h, x:x + w]
            roi = cv2.resize(roi, (200, 200), interpolation=cv2.INTER_LINEAR)

            try:
                params = model.predict(roi)
                label = label_dict[params[0]] if params[0] in label_dict else "Unknown"
                print(f"Predicted label: {params[0]}, Confidence: {params[1]:.2f}")  # Debugging information
                cv2.putText(img, f"{label}, {params[1]:.2f}", (x, y - 20), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)

            except Exception as e:
                print(f"Prediction error: {e}")  # Debugging information
                continue

        cv2.imshow("camera", img)
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break

    camera.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    face_rec()
# Out:
# Predicted label: 1, Confidence: 6492.45
# Predicted label: 1, Confidence: 8145.35
# Predicted label: 1, Confidence: 6614.13
# Predicted label: 1, Confidence: 6417.28
# Predicted label: 1, Confidence: 6453.22
# Predicted label: 1, Confidence: 7627.99
# Predicted label: 1, Confidence: 6453.22
# Predicted label: 1, Confidence: 7627.99
# Predicted label: 1, Confidence: 6277.42
# Predicted label: 1, Confidence: 7638.72
# Predicted label: 1, Confidence: 6390.33
# Predicted label: 1, Confidence: 6178.21
# Predicted label: 1, Confidence: 6128.36
# Predicted label: 1, Confidence: 6128.36
# Predicted label: 1, Confidence: 6120.37
# Predicted label: 1, Confidence: 6250.88
# Predicted label: 1, Confidence: 4886.91
# Predicted label: 1, Confidence: 4960.64
# Predicted label: 1, Confidence: 5393.50
# Predicted label: 1, Confidence: 5060.89
# Predicted label: 1, Confidence: 4975.49
# Predicted label: 1, Confidence: 4928.27
# Predicted label: 1, Confidence: 4983.18
# Predicted label: 1, Confidence: 4983.18
# Predicted label: 1, Confidence: 5743.75
# Predicted label: 1, Confidence: 4973.08
# Predicted label: 1, Confidence: 5700.77
# Predicted label: 1, Confidence: 4958.64
# Predicted label: 1, Confidence: 5190.90
# Predicted label: 1, Confidence: 5269.91
# Predicted label: 1, Confidence: 5269.91
# Predicted label: 1, Confidence: 5494.88
# Predicted label: 1, Confidence: 5150.88
# Predicted label: 1, Confidence: 10944.82
# Predicted label: 1, Confidence: 10944.82
# Predicted label: 1, Confidence: 10944.82
# Predicted label: 1, Confidence: 10599.76
# Predicted label: 1, Confidence: 10470.07
# Predicted label: 1, Confidence: 10470.07
# Predicted label: 1, Confidence: 10470.07
# Predicted label: 1, Confidence: 10564.41
# Predicted label: 1, Confidence: 10537.14
# Predicted label: 1, Confidence: 10537.14
# Predicted label: 1, Confidence: 10467.02
# Predicted label: 1, Confidence: 10672.47
# Predicted label: 1, Confidence: 10672.47
# Predicted label: 1, Confidence: 10672.47
# Predicted label: 1, Confidence: 10730.42
# Predicted label: 1, Confidence: 10778.20
# Predicted label: 1, Confidence: 10778.20
# Predicted label: 1, Confidence: 10792.34
# Predicted label: 1, Confidence: 10792.34
# Predicted label: 1, Confidence: 10853.74
# Predicted label: 1, Confidence: 10853.74
# Predicted label: 1, Confidence: 10840.44
# Predicted label: 1, Confidence: 10840.44
# Predicted label: 1, Confidence: 10840.44
# Predicted label: 1, Confidence: 10938.27
# Predicted label: 1, Confidence: 11006.75
# Predicted label: 1, Confidence: 11006.75
# Predicted label: 1, Confidence: 10949.87
# Predicted label: 1, Confidence: 10949.87
# Predicted label: 1, Confidence: 11039.10
# Predicted label: 1, Confidence: 11068.30
# Predicted label: 1, Confidence: 11068.30
# Predicted label: 1, Confidence: 11068.30
# Predicted label: 1, Confidence: 10975.52
# Predicted label: 1, Confidence: 11010.51
# Predicted label: 1, Confidence: 11010.51
# Predicted label: 1, Confidence: 11055.04
# Predicted label: 1, Confidence: 11055.04
# Predicted label: 1, Confidence: 11066.72
# Predicted label: 1, Confidence: 11066.72
# Predicted label: 1, Confidence: 11081.78
# Predicted label: 1, Confidence: 11081.78
# Predicted label: 1, Confidence: 11032.81
# Predicted label: 1, Confidence: 11032.81
# Predicted label: 1, Confidence: 11122.20
# Predicted label: 1, Confidence: 11008.09
# Predicted label: 1, Confidence: 11008.09
# Predicted label: 1, Confidence: 10919.66
# Predicted label: 1, Confidence: 10919.66
# Predicted label: 1, Confidence: 11460.32
# Predicted label: 1, Confidence: 11484.48
# Predicted label: 1, Confidence: 11484.48
# Predicted label: 1, Confidence: 11511.30
# Predicted label: 1, Confidence: 11511.30
# Predicted label: 1, Confidence: 11470.01
# Predicted label: 1, Confidence: 11483.60
# Predicted label: 1, Confidence: 11483.60
# Predicted label: 1, Confidence: 11483.60
# Predicted label: 1, Confidence: 11462.53
# Predicted label: 1, Confidence: 11462.53
# Predicted label: 1, Confidence: 11411.10
# Predicted label: 1, Confidence: 11411.10
# Predicted label: 1, Confidence: 11408.01
# Predicted label: 1, Confidence: 11408.01
# Predicted label: 1, Confidence: 11391.77
# Predicted label: 1, Confidence: 11389.40
# Predicted label: 1, Confidence: 11356.34
# Predicted label: 1, Confidence: 11356.34
# Predicted label: 1, Confidence: 11356.34
# Predicted label: 1, Confidence: 11344.27
# Predicted label: 1, Confidence: 11347.11
# Predicted label: 1, Confidence: 11347.11
# Predicted label: 1, Confidence: 11374.19
# Predicted label: 1, Confidence: 11374.19
# Predicted label: 1, Confidence: 11361.25
# Predicted label: 1, Confidence: 11361.25
# Predicted label: 1, Confidence: 11372.56
# Predicted label: 1, Confidence: 11426.11
# Predicted label: 1, Confidence: 11426.11
# Predicted label: 1, Confidence: 11424.60
# Predicted label: 1, Confidence: 11424.60
# Predicted label: 1, Confidence: 11401.37
# Predicted label: 1, Confidence: 11371.20
# Predicted label: 1, Confidence: 11371.20
# Predicted label: 1, Confidence: 11394.73
# Predicted label: 1, Confidence: 7940.03
# Predicted label: 1, Confidence: 11394.73
# Predicted label: 1, Confidence: 7940.03
# Predicted label: 1, Confidence: 11361.26
# Predicted label: 1, Confidence: 7756.67
# Predicted label: 1, Confidence: 11326.79
# Predicted label: 1, Confidence: 11326.79
# Predicted label: 1, Confidence: 11340.30
# Predicted label: 1, Confidence: 7993.31
# Predicted label: 1, Confidence: 11340.30
# Predicted label: 1, Confidence: 7993.31
# Predicted label: 1, Confidence: 11320.12
# Predicted label: 1, Confidence: 11322.77
# Predicted label: 1, Confidence: 11322.77
# Predicted label: 1, Confidence: 11345.80
# Predicted label: 1, Confidence: 11345.80
# Predicted label: 1, Confidence: 11380.97
# Predicted label: 1, Confidence: 7915.89
# Predicted label: 1, Confidence: 11367.76
# Predicted label: 1, Confidence: 8072.29
# Predicted label: 1, Confidence: 11367.76
# Predicted label: 1, Confidence: 8072.29
# Predicted label: 1, Confidence: 11407.27
# Predicted label: 1, Confidence: 11407.27
# Predicted label: 1, Confidence: 11363.73
# Predicted label: 1, Confidence: 11363.73
# Predicted label: 1, Confidence: 11399.83
# Predicted label: 1, Confidence: 11399.83
# Predicted label: 1, Confidence: 11356.24
# Predicted label: 1, Confidence: 11378.38
# Predicted label: 1, Confidence: 7767.82
# Predicted label: 1, Confidence: 11378.38
# Predicted label: 1, Confidence: 7767.82
# Predicted label: 1, Confidence: 11374.51
# Predicted label: 1, Confidence: 7865.23
# Predicted label: 1, Confidence: 11374.51
# Predicted label: 1, Confidence: 7865.23
# Predicted label: 1, Confidence: 11350.98
# Predicted label: 1, Confidence: 7968.75
# Predicted label: 1, Confidence: 11355.13
# Predicted label: 1, Confidence: 11355.13
# Predicted label: 1, Confidence: 11367.65
# Predicted label: 1, Confidence: 11367.65
# Predicted label: 1, Confidence: 11339.36
# Predicted label: 1, Confidence: 7740.79
# Predicted label: 1, Confidence: 11341.74
# Predicted label: 1, Confidence: 11341.74
# Predicted label: 1, Confidence: 11349.86
# Predicted label: 1, Confidence: 11349.86
# Predicted label: 1, Confidence: 11322.86
# Predicted label: 1, Confidence: 11389.25
# Predicted label: 1, Confidence: 11389.25
# Predicted label: 1, Confidence: 11390.25
# Predicted label: 1, Confidence: 11390.25
# Predicted label: 1, Confidence: 11361.25
# Predicted label: 1, Confidence: 11361.25
# Predicted label: 1, Confidence: 11363.74
# Predicted label: 1, Confidence: 11363.74
# Predicted label: 1, Confidence: 11361.55
# Predicted label: 1, Confidence: 11361.55
# Predicted label: 1, Confidence: 11367.10
# Predicted label: 1, Confidence: 11378.85
# Predicted label: 1, Confidence: 11385.43
# Predicted label: 1, Confidence: 11385.43
# Predicted label: 1, Confidence: 11423.89
# Predicted label: 1, Confidence: 11423.89
# Predicted label: 1, Confidence: 11359.97
# Predicted label: 1, Confidence: 7815.99
# Predicted label: 1, Confidence: 11409.12
# Predicted label: 1, Confidence: 11409.12
# Predicted label: 1, Confidence: 11423.57
# Predicted label: 1, Confidence: 11423.57
# Predicted label: 1, Confidence: 11352.39
# Predicted label: 1, Confidence: 11403.32
# Predicted label: 1, Confidence: 11403.32
# Predicted label: 1, Confidence: 11343.62
# Predicted label: 1, Confidence: 7791.07
# Predicted label: 1, Confidence: 11343.62
# Predicted label: 1, Confidence: 7791.07
# Predicted label: 1, Confidence: 11339.15
# Predicted label: 1, Confidence: 7946.64
# Predicted label: 1, Confidence: 11363.13
# Predicted label: 1, Confidence: 8011.25
# Predicted label: 1, Confidence: 11314.55
# Predicted label: 1, Confidence: 11314.55
# Predicted label: 1, Confidence: 11375.65
# Predicted label: 1, Confidence: 11375.65
# Predicted label: 1, Confidence: 11401.07
# Predicted label: 1, Confidence: 11380.23
# Predicted label: 1, Confidence: 11366.26
# Predicted label: 1, Confidence: 7868.64
# Predicted label: 1, Confidence: 11366.26
# Predicted label: 1, Confidence: 7868.64
# Predicted label: 1, Confidence: 11317.14
# Predicted label: 1, Confidence: 7931.98
# Predicted label: 1, Confidence: 11317.14
# Predicted label: 1, Confidence: 7931.98
# Predicted label: 1, Confidence: 11344.44
# Predicted label: 1, Confidence: 7785.06
# Predicted label: 1, Confidence: 11374.32
# Predicted label: 1, Confidence: 7895.12
# Predicted label: 1, Confidence: 11397.24
# Predicted label: 1, Confidence: 7937.19
# Predicted label: 1, Confidence: 11397.24
# Predicted label: 1, Confidence: 7937.19
# Predicted label: 1, Confidence: 11383.47
# Predicted label: 1, Confidence: 7882.13
# Predicted label: 1, Confidence: 11383.47
# Predicted label: 1, Confidence: 7882.13
# Predicted label: 1, Confidence: 11332.63
# Predicted label: 1, Confidence: 7795.91
# Predicted label: 1, Confidence: 11285.65
# Predicted label: 1, Confidence: 7809.69
# Predicted label: 1, Confidence: 11278.94
# Predicted label: 1, Confidence: 11278.94
# Predicted label: 1, Confidence: 11302.34
# Predicted label: 1, Confidence: 11302.34
# Predicted label: 1, Confidence: 11298.76
# Predicted label: 1, Confidence: 11339.68
# Predicted label: 1, Confidence: 7893.04
# Predicted label: 1, Confidence: 11339.68
# Predicted label: 1, Confidence: 7893.04
# Predicted label: 1, Confidence: 11311.70
# Predicted label: 1, Confidence: 7880.39
# Predicted label: 1, Confidence: 11311.70
# Predicted label: 1, Confidence: 7880.39
# Predicted label: 1, Confidence: 11121.60
# Predicted label: 1, Confidence: 7965.17
# Predicted label: 1, Confidence: 8061.45
# Predicted label: 1, Confidence: 11123.98
# Predicted label: 1, Confidence: 8121.29
# Predicted label: 1, Confidence: 7955.71
# Predicted label: 1, Confidence: 7874.44
# Predicted label: 1, Confidence: 7874.44
# Predicted label: 1, Confidence: 7976.46
# Predicted label: 1, Confidence: 7867.60
# Predicted label: 1, Confidence: 8161.42
# Predicted label: 1, Confidence: 8161.42
# Predicted label: 1, Confidence: 8096.92
# Predicted label: 1, Confidence: 7954.85
# Predicted label: 1, Confidence: 7954.85
# Predicted label: 1, Confidence: 9040.91
# Predicted label: 1, Confidence: 9040.91
# Predicted label: 1, Confidence: 7831.93
# Predicted label: 1, Confidence: 7332.01
# Predicted label: 1, Confidence: 7070.41
# Predicted label: 1, Confidence: 6979.86
# Predicted label: 1, Confidence: 7078.51
# Predicted label: 1, Confidence: 6875.77
# Predicted label: 1, Confidence: 6867.78
# Predicted label: 1, Confidence: 6687.35
# Predicted label: 1, Confidence: 8488.57
# Predicted label: 1, Confidence: 9052.97
# Predicted label: 1, Confidence: 9150.43
# Predicted label: 1, Confidence: 9037.04
# Predicted label: 1, Confidence: 8950.67
# Predicted label: 1, Confidence: 8950.67
# Predicted label: 1, Confidence: 8889.34
# Predicted label: 1, Confidence: 8686.83
# Predicted label: 1, Confidence: 8673.53
# Predicted label: 1, Confidence: 8673.53
# Predicted label: 1, Confidence: 8597.56
# Predicted label: 1, Confidence: 8485.80
# Predicted label: 1, Confidence: 8535.78
# Predicted label: 1, Confidence: 8635.99
# Predicted label: 1, Confidence: 8687.21
# Predicted label: 1, Confidence: 8693.09
# Predicted label: 1, Confidence: 8540.12
# Predicted label: 1, Confidence: 8429.81
# Predicted label: 1, Confidence: 8240.93
# Predicted label: 1, Confidence: 8201.41
# Predicted label: 1, Confidence: 8200.63
# Predicted label: 1, Confidence: 8196.75
# Predicted label: 1, Confidence: 8210.79
# Predicted label: 1, Confidence: 7980.70
# Predicted label: 1, Confidence: 7956.48
# Predicted label: 1, Confidence: 7777.03
# Predicted label: 1, Confidence: 7777.03
# Predicted label: 1, Confidence: 7749.71
# Predicted label: 1, Confidence: 7866.62
# Predicted label: 1, Confidence: 7866.62
# Predicted label: 1, Confidence: 7710.38
# Predicted label: 1, Confidence: 7583.13
# Predicted label: 1, Confidence: 7717.23
# Predicted label: 1, Confidence: 7720.32
# Predicted label: 1, Confidence: 7796.22
# Predicted label: 1, Confidence: 7390.18
# Predicted label: 1, Confidence: 6267.41
# Predicted label: 1, Confidence: 6104.45
# Predicted label: 1, Confidence: 6135.06
# Predicted label: 1, Confidence: 6423.09
# Predicted label: 1, Confidence: 6658.53
# Predicted label: 1, Confidence: 6876.20
# Predicted label: 1, Confidence: 7191.03
# Predicted label: 1, Confidence: 7487.29
# Predicted label: 1, Confidence: 7487.29
# Predicted label: 1, Confidence: 7170.46
# Predicted label: 1, Confidence: 6761.38
# Predicted label: 1, Confidence: 6882.34
# Predicted label: 1, Confidence: 7176.35
# Predicted label: 1, Confidence: 7176.35
# Predicted label: 1, Confidence: 7195.56
# Predicted label: 1, Confidence: 7665.26
# Predicted label: 1, Confidence: 9419.86
# Predicted label: 1, Confidence: 9419.86
# Predicted label: 1, Confidence: 10130.40
# Predicted label: 1, Confidence: 9899.83
# Predicted label: 1, Confidence: 9899.83
# Predicted label: 1, Confidence: 9194.72
# Predicted label: 1, Confidence: 9240.10
# Predicted label: 1, Confidence: 9149.27
# Predicted label: 1, Confidence: 9033.61
# Predicted label: 1, Confidence: 9033.61
# Predicted label: 1, Confidence: 9065.58
# Predicted label: 1, Confidence: 9199.57
# Predicted label: 1, Confidence: 9199.57
# Predicted label: 1, Confidence: 9147.19
# Predicted label: 1, Confidence: 9135.52
# Predicted label: 1, Confidence: 9120.29
# Predicted label: 1, Confidence: 9120.29
# Predicted label: 1, Confidence: 8845.15
# Predicted label: 1, Confidence: 8845.15
# Predicted label: 1, Confidence: 8375.05
# Predicted label: 1, Confidence: 8881.78
# Predicted label: 1, Confidence: 8609.76
# Predicted label: 1, Confidence: 8609.76
# Predicted label: 1, Confidence: 9117.20
# Predicted label: 1, Confidence: 9117.20
# Predicted label: 1, Confidence: 9191.91
# Predicted label: 1, Confidence: 9029.50
# Predicted label: 1, Confidence: 9055.98
# Predicted label: 1, Confidence: 9055.98
# Predicted label: 1, Confidence: 9114.58
# Predicted label: 1, Confidence: 9160.44
# Predicted label: 1, Confidence: 9160.44
# Predicted label: 1, Confidence: 9004.79
# Predicted label: 1, Confidence: 9042.15
# Predicted label: 1, Confidence: 9042.15
# Predicted label: 1, Confidence: 8986.16
# Predicted label: 1, Confidence: 8994.69
# Predicted label: 1, Confidence: 9005.86
# Predicted label: 1, Confidence: 9005.86
# Predicted label: 1, Confidence: 9002.67
# Predicted label: 1, Confidence: 8905.86
# Predicted label: 1, Confidence: 8905.86
# Predicted label: 1, Confidence: 8938.43
# Predicted label: 1, Confidence: 8910.74
# Predicted label: 1, Confidence: 8910.74
# Predicted label: 1, Confidence: 8921.79
# Predicted label: 1, Confidence: 8891.01
# Predicted label: 1, Confidence: 8891.01
# Predicted label: 1, Confidence: 8949.05
# Predicted label: 1, Confidence: 8928.51
# Predicted label: 1, Confidence: 8877.74
# Predicted label: 1, Confidence: 8877.74
# Predicted label: 1, Confidence: 9000.26
# Predicted label: 1, Confidence: 8919.75
# Predicted label: 1, Confidence: 8919.75
# Predicted label: 1, Confidence: 9038.81
# Predicted label: 1, Confidence: 8982.35
# Predicted label: 1, Confidence: 9107.53
# Predicted label: 1, Confidence: 9037.73
# Predicted label: 1, Confidence: 9037.73
# Predicted label: 1, Confidence: 9055.52
# Predicted label: 1, Confidence: 9055.52
# Predicted label: 1, Confidence: 9102.18
# Predicted label: 1, Confidence: 9003.91
# Predicted label: 1, Confidence: 8930.04
# Predicted label: 1, Confidence: 8930.04
# Predicted label: 1, Confidence: 9056.45
# Predicted label: 1, Confidence: 8960.44
# Predicted label: 1, Confidence: 8960.44
# Predicted label: 1, Confidence: 8941.98
# Predicted label: 1, Confidence: 8944.98
# Predicted label: 1, Confidence: 8977.85
# Predicted label: 1, Confidence: 8977.85
# Predicted label: 1, Confidence: 9015.27
# Predicted label: 1, Confidence: 8964.33
# Predicted label: 1, Confidence: 8964.33
# Predicted label: 1, Confidence: 8999.84
# Predicted label: 1, Confidence: 8974.39
# Predicted label: 1, Confidence: 8980.65
# Predicted label: 1, Confidence: 8980.65
# Predicted label: 1, Confidence: 9011.60
# Predicted label: 1, Confidence: 9013.34
# Predicted label: 1, Confidence: 9041.44
# Predicted label: 1, Confidence: 8937.58
# Predicted label: 1, Confidence: 9001.63
# Predicted label: 1, Confidence: 9018.80
# Predicted label: 1, Confidence: 8981.37
# Predicted label: 1, Confidence: 8990.80
# Predicted label: 1, Confidence: 8952.78
# Predicted label: 1, Confidence: 9051.07
# Predicted label: 1, Confidence: 9147.57
# Predicted label: 1, Confidence: 9750.72
# Predicted label: 1, Confidence: 9828.60
# Predicted label: 1, Confidence: 9799.75
# Predicted label: 1, Confidence: 9799.75
# Predicted label: 1, Confidence: 9815.76
# Predicted label: 1, Confidence: 9835.02
# Predicted label: 1, Confidence: 9824.86
# Predicted label: 1, Confidence: 9824.86
# Predicted label: 1, Confidence: 9878.68
# Predicted label: 1, Confidence: 9805.03
# Predicted label: 1, Confidence: 9791.40
# Predicted label: 1, Confidence: 9802.21
# Predicted label: 1, Confidence: 9767.90
# Predicted label: 1, Confidence: 9779.91
# Predicted label: 1, Confidence: 9927.04
# Predicted label: 1, Confidence: 9927.04
# Predicted label: 1, Confidence: 9395.03
# Predicted label: 1, Confidence: 9365.99
# Predicted label: 1, Confidence: 8326.67
# Predicted label: 1, Confidence: 8173.37
# Predicted label: 1, Confidence: 8166.35
# Predicted label: 1, Confidence: 8059.47
# Predicted label: 1, Confidence: 8274.06
# Predicted label: 1, Confidence: 8336.28
# Predicted label: 1, Confidence: 8491.60
# Predicted label: 1, Confidence: 8491.60
# Predicted label: 1, Confidence: 8540.86
# Predicted label: 1, Confidence: 8550.95
# Predicted label: 1, Confidence: 8613.68
# Predicted label: 1, Confidence: 8454.98
# Predicted label: 1, Confidence: 8050.88
# Predicted label: 1, Confidence: 8163.65
# Predicted label: 1, Confidence: 8062.77
# Predicted label: 1, Confidence: 8272.14
# Predicted label: 1, Confidence: 6442.09
# Predicted label: 1, Confidence: 6810.46
# Predicted label: 1, Confidence: 6144.65
# Predicted label: 1, Confidence: 6810.46
# Predicted label: 1, Confidence: 6144.65
# Predicted label: 1, Confidence: 7000.38

# %%
import numpy as np
import os
import cv2

# Load Haar cascade for face detection
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

# Paths
dataset_path = "JOHN/"
model_path = "face_model_fisher.yml"
label_dict_path = "label_dictionary_fisher.npy"

def read_images(path):
    """ Reads images, detects faces, and prepares training data. """
    X, y = [], []
    label_dict = {}
    label_id = 0  

    for subdirname in os.listdir(path):
        subject_path = os.path.join(path, subdirname)
        if not os.path.isdir(subject_path):
            continue  

        label_dict[label_id] = subdirname  

        for filename in os.listdir(subject_path):
            filepath = os.path.join(subject_path, filename)
            img = cv2.imread(filepath, cv2.IMREAD_GRAYSCALE)

            if img is None:
                print(f"Skipping {filename}: Invalid image")
                continue  

            faces = face_cascade.detectMultiScale(img, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
            if len(faces) == 0:
                print(f"Skipping {filename}: No face detected")
                continue  

            for (x, y_, w, h) in faces:
                face = img[y_:y_ + h, x:x + w]
                face = cv2.resize(face, (200, 200))

                X.append(face)
                y.append(label_id)

        label_id += 1

    return X, y, label_dict

# Read images and extract faces
print("Reading images and training the FisherFace model...")
X, y, label_dict = read_images(dataset_path)

if len(X) == 0 or len(y) == 0:
    print("Error: No faces found. Check your dataset.")
    exit()

# Convert X and y to correct NumPy array format
X = np.array(X, dtype=np.uint8)
y = np.array(y, dtype=np.int32)

# Create FisherFace recognizer
recognizer = cv2.face.FisherFaceRecognizer_create()

# Train the recognizer
recognizer.train(X, y)

# Save trained model and labels
recognizer.save(model_path)
np.save(label_dict_path, label_dict)

print(f"Training complete! Model saved as '{model_path}'. Label dictionary saved as '{label_dict_path}'.")
print("Label dictionary:", label_dict)

# Load the trained model and label dictionary for testing
recognizer.read(model_path)
label_dict = np.load(label_dict_path, allow_pickle=True).item()

# Test the recognizer with a sample image
def test_recognizer(image_path):
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    faces = face_cascade.detectMultiScale(img, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
    for (x, y, w, h) in faces:
        face = img[y:y + h, x:x + w]
        face = cv2.resize(face, (200, 200))
        label, confidence = recognizer.predict(face)
        print(f"Predicted label: {label_dict[label]}, Confidence: {confidence:.2f}")

# Test with sample images
test_recognizer("path_to_john_image.jpg")
test_recognizer("path_to_naomi_image.jpg")
# Out:
# Reading images and training the FisherFace model...
# Skipping 478862282_2704535509737971_2319760447268798302_n.jpg: No face detected
# Training complete! Model saved as 'face_model_fisher.yml'. Label dictionary saved as 'label_dictionary_fisher.npy'.
# Label dictionary: {0: 'john', 1: 'naomi'}

# %%
import numpy as np
import cv2
import os

def read_images(path, face_cascade):
    """ Reads images from the dataset and prepares training data. """
    X, y = [], []
    label_dict = {}
    label_id = 0

    for subdirname in os.listdir(path):
        subject_path = os.path.join(path, subdirname)
        if not os.path.isdir(subject_path):
            continue

        label_dict[label_id] = subdirname

        for filename in os.listdir(subject_path):
            filepath = os.path.join(subject_path, filename)
            img = cv2.imread(filepath, cv2.IMREAD_GRAYSCALE)

            if img is None:
                continue

            faces = face_cascade.detectMultiScale(img, scaleFactor=1.8, minNeighbors=5, minSize=(30, 30))
            for (x, y_, w, h) in faces:
                face = img[y_:y_ + h, x:x + w]
                face = cv2.resize(face, (200, 200))
                X.append(face)
                y.append(label_id)

        label_id += 1

    return np.array(X, dtype=np.uint8), np.array(y, dtype=np.int32), label_dict  # Return label_dict

def face_rec():
    dataset_path = "JOHN/"  
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    X, y, label_dict = read_images(dataset_path, face_cascade)

    model = cv2.face.EigenFaceRecognizer_create()
    model.train(X, y)

    camera = cv2.VideoCapture(0)

    while True:
        ret, img = camera.read()
        if not ret:
            break

        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)  
        faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

        for (x, y, w, h) in faces:
            cv2.rectangle(img, (x, y), (x + w, y + h), (255, 0, 0), 2)
            roi = gray[y:y + h, x:x + w]
            roi = cv2.resize(roi, (200, 200), interpolation=cv2.INTER_LINEAR)

            try:
                params = model.predict(roi)
                label = label_dict[params[0]] if params[0] in label_dict else "Unknown"
                print(f"Predicted label: {params[0]}, Confidence: {params[1]:.2f}")  # Debugging information
                cv2.putText(img, f"{label}, {params[1]:.2f}", (x, y - 20), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)

            except Exception as e:
                print(f"Prediction error: {e}")  # Debugging information
                continue

        cv2.imshow("camera", img)
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break

    camera.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    face_rec()
# Out:
# Predicted label: 0, Confidence: 7799.85
# Predicted label: 0, Confidence: 7487.09
# Predicted label: 0, Confidence: 8269.83
# Predicted label: 0, Confidence: 8087.18
# Predicted label: 0, Confidence: 7696.69
# Predicted label: 0, Confidence: 8386.73
# Predicted label: 1, Confidence: 9108.35
# Predicted label: 1, Confidence: 9224.65
# Predicted label: 0, Confidence: 9090.80
# Predicted label: 1, Confidence: 8978.53
# Predicted label: 1, Confidence: 9251.27
# Predicted label: 1, Confidence: 9051.09
# Predicted label: 1, Confidence: 8942.49
# Predicted label: 1, Confidence: 8921.57
# Predicted label: 0, Confidence: 8536.98
# Predicted label: 1, Confidence: 9252.88
# Predicted label: 0, Confidence: 8877.75
# Predicted label: 0, Confidence: 8622.65
# Predicted label: 0, Confidence: 8684.07
# Predicted label: 1, Confidence: 8116.82
# Predicted label: 1, Confidence: 7341.62
# Predicted label: 1, Confidence: 7551.08
# Predicted label: 1, Confidence: 7648.10
# Predicted label: 1, Confidence: 7535.31
# Predicted label: 1, Confidence: 7609.95
# Predicted label: 1, Confidence: 7547.76
# Predicted label: 1, Confidence: 7508.52
# Predicted label: 1, Confidence: 7466.15
# Predicted label: 1, Confidence: 7451.82
# Predicted label: 1, Confidence: 7724.56
# Predicted label: 1, Confidence: 7630.19
# Predicted label: 1, Confidence: 6919.04
# Predicted label: 1, Confidence: 7207.82
# Predicted label: 1, Confidence: 7023.21
# Predicted label: 1, Confidence: 7026.03
# Predicted label: 1, Confidence: 7030.54
# Predicted label: 1, Confidence: 7105.82
# Predicted label: 1, Confidence: 7363.13
# Predicted label: 1, Confidence: 8643.66
# Predicted label: 0, Confidence: 8334.78
# Predicted label: 0, Confidence: 8810.15
# Predicted label: 0, Confidence: 8788.05
# Predicted label: 0, Confidence: 8385.64
# Predicted label: 0, Confidence: 8637.81
# Predicted label: 0, Confidence: 8749.85
# Predicted label: 0, Confidence: 8443.10
# Predicted label: 1, Confidence: 8687.31
# Predicted label: 1, Confidence: 8593.30
# Predicted label: 1, Confidence: 8729.86
# Predicted label: 1, Confidence: 8676.02
# Predicted label: 1, Confidence: 8512.08
# Predicted label: 1, Confidence: 8415.85
# Predicted label: 0, Confidence: 8798.90
# Predicted label: 0, Confidence: 7590.08
# Predicted label: 0, Confidence: 7947.96
# Predicted label: 0, Confidence: 7631.76
# Predicted label: 0, Confidence: 7830.64
# Predicted label: 0, Confidence: 8274.60
# Predicted label: 0, Confidence: 7868.09
# Predicted label: 0, Confidence: 7989.54
# Predicted label: 0, Confidence: 7208.15
# Predicted label: 0, Confidence: 6998.23
# Predicted label: 0, Confidence: 7325.64
# Predicted label: 0, Confidence: 7703.51
# Predicted label: 0, Confidence: 7741.13
# Predicted label: 0, Confidence: 7349.33
# Predicted label: 0, Confidence: 6502.17
# Predicted label: 0, Confidence: 8020.73
# Predicted label: 0, Confidence: 7636.22
# Predicted label: 0, Confidence: 6597.61
# Predicted label: 0, Confidence: 7408.97
# Predicted label: 0, Confidence: 7526.97
# Predicted label: 0, Confidence: 8135.77
# Predicted label: 0, Confidence: 7508.64
# Predicted label: 0, Confidence: 8040.97
# Predicted label: 0, Confidence: 7595.40
# Predicted label: 0, Confidence: 7750.95
# Predicted label: 0, Confidence: 7420.97
# Predicted label: 0, Confidence: 7756.03
# Predicted label: 0, Confidence: 8272.53
# Predicted label: 0, Confidence: 7423.26
# Predicted label: 0, Confidence: 8049.63
# Predicted label: 0, Confidence: 7257.08
# Predicted label: 0, Confidence: 7614.44
# Predicted label: 0, Confidence: 7935.65
# Predicted label: 0, Confidence: 7889.95
# Predicted label: 0, Confidence: 8466.05
# Predicted label: 1, Confidence: 8179.98
# Predicted label: 1, Confidence: 8288.64
# Predicted label: 1, Confidence: 8630.98
# Predicted label: 1, Confidence: 8076.71
# Predicted label: 1, Confidence: 8075.28
# Predicted label: 1, Confidence: 7658.45
# Predicted label: 1, Confidence: 7674.14
# Predicted label: 1, Confidence: 9550.62
# Predicted label: 1, Confidence: 8989.11
# Predicted label: 1, Confidence: 8989.11
# Predicted label: 1, Confidence: 8529.89
# Predicted label: 1, Confidence: 8301.93
# Predicted label: 1, Confidence: 8301.93
# Predicted label: 1, Confidence: 8186.55
# Predicted label: 1, Confidence: 8273.46
# Predicted label: 1, Confidence: 8392.63
# Predicted label: 1, Confidence: 8392.63
# Predicted label: 1, Confidence: 8503.88
# Predicted label: 1, Confidence: 8387.87
# Predicted label: 1, Confidence: 8391.23
# Predicted label: 1, Confidence: 8372.07
# Predicted label: 1, Confidence: 8237.17
# Predicted label: 1, Confidence: 8237.17
# Predicted label: 1, Confidence: 8143.06
# Predicted label: 1, Confidence: 8181.96
# Predicted label: 1, Confidence: 8127.48
# Predicted label: 1, Confidence: 8011.55
# Predicted label: 1, Confidence: 8011.55

# %% [markdown]
# **Question: The `predict()` method returns a two-element array. Provide your analysis of the two returned values and their important ince this application.**

# %% [markdown]
# ## 4. Supplementary Activity

# %% [markdown]
# Your accomplisment of the tasks below contribute to the achievement of ILO1, ILO2, and ILO3 for this module.
#
# ---
#
# Tasks:
# 1. Create a new dataset for testing, this dataset must include the following:
#   - The same person/s that the model has to recognize.
#   - Different person/s that the model should not recognize.
# 2. For each model, perform 20 tests. Document the testing performed and provide observations.
# 3. Conclude on the performed tests by providing your evaluation of the performance of the models.

# %% [markdown]
# ## 5. Summary, Conclusions and Lessons Learned

# %% [markdown]
# <hr/>
#
# ***Proprietary Clause***
#
# *Property of the Technological Institute of the Philippines (T.I.P.). No part of the materials made and uploaded in this learning management system by T.I.P. may be copied, photographed, printed, reproduced, shared, transmitted, translated, or reduced to any electronic medium or machine-readable form, in whole or in part, without the prior consent of T.I.P.*
